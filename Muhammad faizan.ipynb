# %%
#Data science bootcamp by google developer
#DAY 1


#Printing
print("hello world ")
name="faizan"
print(f"hello {name}")
# Out:
# hello world
# hello faizan

# %%
#Quick test
accuracy=0.3556
print(f"Accuracy {accuracy :.2%}")
# Out:
# Accuracy 35.56%

# %%
#Quick test
sname="ali"
status=" "
if (status=="PASS"):
   print("Result status of",sname, " is pass",type(status))
else:
   print("Result status of ",sname,"is Fail",type(status))
# Out:
# Result status of  ali is Fail <class 'str'>

# %%
#Quick test
x="5"
y=2
print(x*y)
# Out:
# 55

# %%
#conditional statement
marks=int(input("enter your marks"))
if  marks >=85:
  print("Grade: A")
elif marks >=80:
  print("Grade: A-")
elif marks >=75:
  print("Grade: B")
elif marks >=75:
  print("Grade: B-")
elif marks >=70:
  print("Grade: C")
elif marks >=65:
  print("Grade: C-")
else:
  print("Enter a valid marks")
# Out:
# enter your marks80
# Grade: A-

# %%
#Loops
for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
names=["ali","zainab","esha","zaryab","saad","sadia"]
for name in names:
    print(name)
# Out:
# ali
# zainab
# esha
# zaryab
# saad
# sadia

# %%
for i in range(2,8,2):
  print(i)
# Out:
# 2
# 4
# 6

# %%
#while loop
count=5
while count>0:
  print(count)
  count=count-1
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
#function
def greet(name):
  print("hello",name)
result=greet("ali")
print(result)
# Out:
# hello ali
# None

# %%
#quick test
def double(n):
  return n*2

print(double(double(3)))
# Out:
# 12

# %%
#list in python and then indexing
data=[10,23,4,5,6,7]
print(data[1:4])
# Out:
# [23, 4, 5]

# %%
#tuples (immutable)
tup1=(1,2,3,4,5,6,7)
print(tup1[1])
tup1[1]=3
print(tup1)
# Out:
# 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_618/3909030197.py in <cell line: 0>()
#       2 tup1=(1,2,3,4,5,6,7)
#       3 print(tup1[1])
# ----> 4 tup1[1]=3
#       5 print(tup1)
#
# TypeError: 'tuple' object does not support item assignment

# %%
#sets in python
set1={"apple","banana","cherrry","mango","grapes"}
print(set1)
# Out:
# {'apple', 'mango', 'cherrry', 'grapes', 'banana'}

# %%
#dictionaries
student={
    "name":"ali",
    "age":20,
    "city":"islamabad"
}
print(student)
# Out:
# {'name': 'ali', 'age': 20, 'city': 'islamabad'}

# %%
student={
    "name":"ali",
    "age":20,
    "age":21,
    "city":"islamabad"
}
print(student["age"])
# Out:
# 21
